# %%
from Algorithms.Utils.dataset import get_brown_as_universal


dataset = get_brown_as_universal()

print(len(dataset))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 6
#       1 # import sys
#       2 # import os
#       3
#       4 # sys.path.append(os.path.join(os.path.dirname(__file__), "..", ".."))
# ----> 6 from Algorithms.Utils.dataset import get_brown_as_universal
#       9 dataset = get_brown_as_universal()
#      11 print(len(dataset))
#
# ModuleNotFoundError: No module named 'Algorithms'
